# %%
#------------------------------------------------------------------------------------------------------------------------------
# Install dependencies first
#------------------------------------------------------------------------------------------------------------------------------
# pip install requests
# pip install psycopg2
# pip install spotipy
# pip install circlify
# pip install pandas
# pip install matplotlib

# %%
#------------------------------------------------------------------------------------------------------------------------------
# Import module
#------------------------------------------------------------------------------------------------------------------------------
from musicmagic import *

warnings.filterwarnings("ignore")

# %%
artist0 = "britney spears"
song0 = "toxic"

artist1 = 'lady gaga'
song1 = 'just dance'

#------------------------------------------------------------------------------------------------------------------------------
# Input two artists and respective songs
#------------------------------------------------------------------------------------------------------------------------------
# artist0 = input('pick artist? ').title()
# song0 = input(f'pick song for {artist0}? ').title()

# artist1 = input('pick artist? ').title()
# song1 = input(f'pick song for {artist1}? ').title()

# %%
search_sim_artist(artist0)
search_sim_artist(artist1)
# Out:
# ARE YOU SEARCHING FOR?
# Britney Spears
# ARE YOU SEARCHING FOR?
# Lady Gaga

# %%
search_artist_bio(artist0)
search_artist_bio(artist1)
# Out:
# INTRO TO YOUR ARTIST - Britney Spears:
# Genres: Pop, Dance, Female Vocalists, Legend
# Playcounts: 248,360,157
# Listeners: 3,920,653
# Playcounts per listener: 63
# Bio: Britney Jean Spears (born December 2, 1981) is a Grammy-winning multi-platinum American pop singer, songwriter, dancer and occasional actress. She debuted in 1998 with her single ...Baby One More Time. She is one of the most influential and popular post-2000 icons of music. She also holds several world records. She has officially released nine studio albums to date: ...Baby One More Time (1999), Oops!... I Did It Again (2000), Britney (2001), In the Zone (2003)
# https://last.fm/music/Britney+Spears/+wiki
#
# INTRO TO YOUR ARTIST - Lady Gaga:
# Genres: Pop, Dance, Electronic, Female Vocalists, Female Vocalist
# Playcounts: 414,350,114
# Listeners: 4,603,750
# Playcounts per listener: 90
# Bio: Stefani Joanne Angelina Germanotta, who performs under the stage name Lady Gaga (born March 28,1986 in New York, NY) is an Academy Award, Golden Globe & Grammy-winner singer, songwriter and musician from New York City, New York, United States. Before Gaga adopted her stage name she was in a band called Stefani Germanotta Band. She released her first EP, “Red and Blue, in early 2006. The following year, music producer Rob Fusari dubbed her Lady Gaga, inspired by the Queen song Radio Ga Ga.
# https://last.fm/music/Lady+Gaga/+wiki

# %%
main_circles_v2(artist0, artist1)
main_bars(artist0, artist1)
# Out:
# See what britney spears looks like! https://i.scdn.co/image/ab6761610000e5ebf2ac13247b26025069dbdc4e
# See what lady gaga looks like! https://i.scdn.co/image/ab6761610000e5eb749ba770a33230206f8fe159
# lady gaga is the more popular artist!

# %%
main_songs(artist0, song0, artist1, song1)
# Out:
# TOP 10 SONG(S) YOU MAY ALSO LIKE:
# ----------------------------------------------------------------------------------------------------
# Lady Gaga - Poker Face
# Rihanna - S&M
# Madonna - Hung Up
# Gwen Stefani - Hollaback Girl
# Nelly Furtado - Promiscuous
# Rihanna - Only Girl (In the World)
# Katy Perry - Hot n Cold
# Nelly Furtado - Maneater
# Kylie Minogue - Can't Get You Out of My Head
# The Pussycat Dolls - When I Grow Up

# %%
main_artists(artist0, artist1)
# Out:
# TOP 10 ARTIST(S) YOU MAY ALSO LIKE:
# ----------------------------------------------------------------------------------------------------
# Christina Aguilera
# Madonna
# Lindsay Lohan
# Hilary Duff
# The Pussycat Dolls
# Paris Hilton
# Kylie Minogue
# Jennifer Lopez
# Gwen Stefani
# Mariah Carey
