# %%
#------------------------------------------------------------------------------------------------------------------------------
# Install dependencies first
#------------------------------------------------------------------------------------------------------------------------------
# pip install requests
# pip install psycopg2
# pip install spotipy
# pip install circlify
# pip install pandas
# pip install matplotlib

# %%
#------------------------------------------------------------------------------------------------------------------------------
# Import module
#------------------------------------------------------------------------------------------------------------------------------
from musicmagic import *

warnings.filterwarnings("ignore")

# %%
# artist0 = "justin bieber"
# song0 = "peaches"

# artist1 = 'drake'
# song1 = 'one dance'

#------------------------------------------------------------------------------------------------------------------------------
# Input two artists and respective songs
#------------------------------------------------------------------------------------------------------------------------------
artist0 = input('pick artist? ').title()
song0 = input(f'pick song for {artist0}? ').title()

artist1 = input('pick artist? ').title()
song1 = input(f'pick song for {artist1}? ').title()
# Out:
# pick artist? justin bieber
# pick song for Justin Bieber? peaches
# pick artist? drake
# pick song for Drake? one dance

# %%
search_sim_artist(artist0)
search_sim_artist(artist1)
# Out:
# ARE YOU SEARCHING FOR?
# Justin Bieber
# ARE YOU SEARCHING FOR?
# Drake
# Nick Drake
# Cosmo Sheldrake
# Drakeford

# %%
search_artist_bio(artist0)
search_artist_bio(artist1)
# Out:
# INTRO TO YOUR ARTIST - Justin Bieber:
# Genres: Pop, Black Metal, Justin Bieber, Rnb, Hip Hop
# Playcounts: 103,652,355
# Listeners: 2,418,961
# Playcounts per listener: 42
# Bio: Justin Drew Bieber (born March 1, 1994 in London, Ontario, Canada) is a Canadian pop musician, actor, and singer-songwriter. Bieber was discovered in 2008 by American talent manager Scooter Braun, who came across Biebers videos on YouTube and later became his manager. Braun arranged for him to meet with entertainer Usher Raymond in Atlanta, Georgia. Bieber was signed to Raymond Braun Media Group (RBMG), and then to an Island Records recording contract offered by record executive L.A. Reid.
# https://last.fm/music/Justin+Bieber/+wiki
#
# INTRO TO YOUR ARTIST - Drake:
# Genres: Hip Hop, Rap, Rnb, Canadian
# Playcounts: 268,622,689
# Listeners: 4,215,855
# Playcounts per listener: 63
# Bio: Aubrey Drake Graham (born October 24, 1986) is a Canadian rapper, singer, songwriter, record producer, actor, and businessman. Drake was an actor on the teen drama television series Degrassi: The Next Generation in the early 2000s. Intent on pursuing a career in music, he left the series in 2007 after releasing his debut mixtape, Room for Improvement. He released two further independent projects, Comeback Season and So Far Gone, before signing to Lil Waynes Young Money Entertainment in June 2009.
# https://last.fm/music/Drake/+wiki
#
# INTRO TO YOUR ARTIST - Nick Drake:
# Genres: Folk, Singer Songwriter, Acoustic, Indie, Mellow
# Playcounts: 52,461,867
# Listeners: 1,596,020
# Playcounts per listener: 32
# Bio: Nick Drake (Nicholas Rodney Drake, Rangoon, Burma, June 19, 1948 - Tanworth-in-Arden, England, November 25, 1974) was an English folk singer known for his gentle, enigmatic songs and his virtuosic right-hand finger picking technique. Although he recorded only three albums, critics and fellow musicians hold his work in very high esteem. Drake failed to find a wide audience during his lifetime and had a strong aversion to performing. Since his death, however, Drakes music has gained a significant cult following.
# https://last.fm/music/Nick+Drake/+wiki
#
# INTRO TO YOUR ARTIST - Cosmo Sheldrake:
# Genres: Electronic, Folktronica, Experimental, Seen Live, Indie
# Playcounts: 2,290,281
# Listeners: 166,627
# Playcounts per listener: 13
# Bio: Cosmo Sheldrake is a London based master looper, vocalist and multi-instrumentalist. As composer and producer, he has written music for film and theatre. Cosmo also performs with his older brother Merlin in the Gentle Mystics, who released their debut album in 2011. http://www.cosmosheldrake.com
# https://last.fm/music/Cosmo+Sheldrake/+wiki
#
# INTRO TO YOUR ARTIST - Drakeford:
# Genres: Singer Songwriter
# Playcounts: 17,781
# Listeners: 3,963
# Playcounts per listener: 4
# Bio: Drakeford is an American duo based out of Chattanooga, TN, comprising husband and wife Drake and Lucy-Jayne Lanier.
# https://last.fm/music/Drakeford/+wiki

# %%
main_circles_v2(artist0, artist1)
main_bars(artist0, artist1)
# Out:
# See what Justin Bieber looks like! https://i.scdn.co/image/ab6761610000e5eb70783ea42c106f3f325f53af
# See what Drake looks like! https://i.scdn.co/image/ab6761610000e5eb9e46a78c5cd2f7a8e7669980
# Drake is the more popular artist!

# %%
main_songs(artist0, song0, artist1, song1)
# Out:
# TOP SONG(S) YOU MAY ALSO LIKE:
# ----------------------------------------------------------------------------------------------------
# Destiny's Child - Say My Name
# Normani - Wild Side (feat. Cardi B)
# Normani - Motivation
# Zayn - PILLOWTALK
# Selena Gomez - Good for You
# Little Mix - Woman Like Me (feat. Nicki Minaj)
# Jhené Aiko - P*$$Y Fairy (OTW)
# Ciara - Like a Boy
# Kehlani - Toxic
# Jesy Nelson - Boyz (feat. Nicki Minaj)
# Mariah Carey - We Belong Together
# Nelly - Dilemma
# Post Malone - Sunflower - Spider-Man: Into the Spider-Verse
# Destiny's Child - Bills, Bills, Bills
# Eminem - The Monster
# DJ Khaled - Wild Thoughts (feat. Rihanna & Bryson Tiller)
# Ty Dolla $ign - Spicy (feat. Post Malone)
# Ty Dolla $ign - Expensive (feat. Nicki Minaj)
# Missy Elliott - Get Ur Freak On
# Missy Elliott - Work It
# Chris Brown - Loyal (feat. Lil Wayne & Tyga)
# Jessie J - Bang Bang
# Mariah Carey - Obsessed

# %%
main_artists(artist0, artist1)
# Out:
# TOP ARTIST(S) YOU MAY ALSO LIKE:
# ----------------------------------------------------------------------------------------------------
# Chris Brown
# Post Malone
# The Weeknd
# Usher
# Nicki Minaj
# Jeremih
# Omarion
# Ty Dolla $ign
# Bryson Tiller
